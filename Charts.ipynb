# %% [markdown]
# <a href="https://colab.research.google.com/github/architnd/python-colab/blob/main/Charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a sample DataFrame
data = {
    'Category': ['A', 'B', 'C', 'D', 'E'],
    'Value': [25, 40, 30, 55, 20]
}
df = pd.DataFrame(data)

print("Sample DataFrame:")
display(df)
# Out:
# Sample DataFrame:
#   Category  Value
# 0        A     25
# 1        B     40
# 2        C     30
# 3        D     55
# 4        E     20

# %% [markdown]
# Now, let's visualize this DataFrame using a bar plot with `matplotlib`.

# %%
# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(df['Category'], df['Value'], color='skyblue')
plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Sample Data Visualization')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
